# %%
# TensorFlow와 GPU 관련 패키지 설치
pip install tensorflow tensorflow-gpu

# 기타 라이브러리 설치
pip install numpy pandas chardet faiss-gpu sentence-transformers langchain langchain-community pypdf pdfplumber
pip install langchain-ollama tf-keras
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/joonhai/.local/lib/python3.10/site-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
# Requirement already satisfied: pandas in /home/joonhai/.local/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: trl in /home/joonhai/.local/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: sentence_transformers in /home/joonhai/.local/lib/python3.10/site-packages (3.3.1)
# Requirement already satisfied: bitsandbytes in /home/joonhai/.local/lib/python3.10/site-packages (0.44.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/joonhai/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/joonhai/.local/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: datasets>=2.21.0 in /home/joonhai/.local/lib/python3.10/site-packages (from trl) (3.1.0)
# Requirement already satisfied: transformers>=4.46.0 in /home/joonhai/.local/lib/python3.10/site-packages (from trl) (4.46.3)
# Requirement already satisfied: accelerate>=0.34.0 in /home/joonhai/.local/lib/python3.10/site-packages (from trl) (1.1.1)
# Requirement already satisfied: rich in /home/joonhai/.local/lib/python3.10/site-packages (from trl) (13.9.4)
# Requirement already satisfied: scikit-learn in /home/joonhai/.local/lib/python3.10/site-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/joonhai/.local/lib/python3.10/site-packages (from sentence_transformers) (0.26.3)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from sentence_transformers) (1.8.0)
# Requirement already satisfied: tqdm in /home/joonhai/.local/lib/python3.10/site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/joonhai/.local/lib/python3.10/site-packages (from sentence_transformers) (2.5.1)
# Requirement already satisfied: Pillow in /home/joonhai/.local/lib/python3.10/site-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/joonhai/.local/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (0.4.5)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from accelerate>=0.34.0->trl) (5.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/joonhai/.local/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (24.2)
# Requirement already satisfied: psutil in /home/joonhai/.local/lib/python3.10/site-packages (from accelerate>=0.34.0->trl) (6.1.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/joonhai/.local/lib/python3.10/site-packages (from datasets>=2.21.0->trl) (0.70.16)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (2.32.3)
# Requirement already satisfied: filelock in /home/joonhai/.local/lib/python3.10/site-packages (from datasets>=2.21.0->trl) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/joonhai/.local/lib/python3.10/site-packages (from datasets>=2.21.0->trl) (18.1.0)
# Requirement already satisfied: fsspec[http]<=2024.9.0,>=2023.1.0 in /home/joonhai/.local/lib/python3.10/site-packages (from datasets>=2.21.0->trl) (2024.9.0)
# Requirement already satisfied: xxhash in /home/joonhai/.local/lib/python3.10/site-packages (from datasets>=2.21.0->trl) (3.5.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/joonhai/.local/lib/python3.10/site-packages (from datasets>=2.21.0->trl) (0.3.8)
# Requirement already satisfied: aiohttp in /home/joonhai/.local/lib/python3.10/site-packages (from datasets>=2.21.0->trl) (3.11.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/joonhai/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: six>=1.5 in /home/joonhai/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.3.1.170)
# Requirement already satisfied: sympy==1.13.1 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.11.0->sentence_transformers) (3.0.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.4.5.8)
# Requirement already satisfied: triton==3.1.0 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (11.6.1.9)
# Requirement already satisfied: networkx in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/joonhai/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (2.21.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/joonhai/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/joonhai/.local/lib/python3.10/site-packages (from transformers>=4.46.0->trl) (2024.11.6)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/joonhai/.local/lib/python3.10/site-packages (from transformers>=4.46.0->trl) (0.20.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/joonhai/.local/lib/python3.10/site-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/joonhai/.local/lib/python3.10/site-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/joonhai/.local/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/joonhai/.local/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.21.0->trl) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.21.0->trl) (1.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.21.0->trl) (2.4.3)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.21.0->trl) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.21.0->trl) (1.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (24.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.21.0->trl) (0.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.21.0->trl) (6.1.0)
# Requirement already satisfied: mdurl~=0.1 in /home/joonhai/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (1.26.5)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.1.3 which is incompatible.
# langchain 0.3.9 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 2.1.3 which is incompatible.
# langchain-community 0.3.8 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 2.1.3 which is incompatible.
# Successfully installed numpy-2.1.3
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in /home/joonhai/.local/lib/python3.10/site-packages (0.3.9)
# Requirement already satisfied: langchain-community in /home/joonhai/.local/lib/python3.10/site-packages (0.3.8)
# Requirement already satisfied: pypdf in /home/joonhai/.local/lib/python3.10/site-packages (5.1.0)
# Requirement already satisfied: pdfplumber in /home/joonhai/.local/lib/python3.10/site-packages (0.11.4)
# Requirement already satisfied: faiss-cpu in /home/joonhai/.local/lib/python3.10/site-packages (1.9.0.post1)
# Collecting numpy<2,>=1.22.4
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/lib/python3/dist-packages (from langchain) (5.4.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain) (0.1.147)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain) (2.0.35)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain) (2.10.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain) (3.11.8)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain) (0.3.21)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: typing_extensions>=4.0 in /home/joonhai/.local/lib/python3.10/site-packages (from pypdf) (4.12.2)
# Requirement already satisfied: Pillow>=9.1 in /home/joonhai/.local/lib/python3.10/site-packages (from pdfplumber) (11.0.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /home/joonhai/.local/lib/python3.10/site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: pdfminer.six==20231228 in /home/joonhai/.local/lib/python3.10/site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /home/joonhai/.local/lib/python3.10/site-packages (from pdfminer.six==20231228->pdfplumber) (44.0.0)
# Requirement already satisfied: packaging in /home/joonhai/.local/lib/python3.10/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/joonhai/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/joonhai/.local/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/joonhai/.local/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/joonhai/.local/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/joonhai/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/joonhai/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/joonhai/.local/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2->langchain) (2020.6.20)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2->langchain) (1.26.5)
# Requirement already satisfied: greenlet!=0.4.17 in /home/joonhai/.local/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain) (2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/joonhai/.local/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/joonhai/.local/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# Successfully installed numpy-1.26.4
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-ollama in /home/joonhai/.local/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: rank_bm25 in /home/joonhai/.local/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: tf-keras in /home/joonhai/.local/lib/python3.10/site-packages (2.18.0)
# Requirement already satisfied: chardet in /usr/lib/python3/dist-packages (4.0.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-ollama) (0.3.21)
# Requirement already satisfied: ollama<1,>=0.3.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-ollama) (0.4.2)
# Requirement already satisfied: numpy in /home/joonhai/.local/lib/python3.10/site-packages (from rank_bm25) (1.26.4)
# Requirement already satisfied: tensorflow<2.19,>=2.18 in /home/joonhai/.local/lib/python3.10/site-packages (from tf-keras) (2.18.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (0.1.147)
# Requirement already satisfied: PyYAML>=5.3 in /usr/lib/python3/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (5.4.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (4.12.2)
# Requirement already satisfied: packaging<25,>=23.2 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.10.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/joonhai/.local/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (1.33)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /home/joonhai/.local/lib/python3.10/site-packages (from ollama<1,>=0.3.0->langchain-ollama) (0.27.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (59.6.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.4.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.4.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.68.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (4.25.5)
# Requirement already satisfied: six>=1.12.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.5.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.6.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (24.3.25)
# Requirement already satisfied: keras>=3.5.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (18.1.1)
# Requirement already satisfied: h5py>=3.11.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.37.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.1.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.32.3)
# Requirement already satisfied: wrapt>=1.11.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow<2.19,>=2.18->tf-keras) (0.37.1)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (2020.6.20)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (3.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.0)
# Requirement already satisfied: namex in /home/joonhai/.local/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /home/joonhai/.local/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.13.1)
# Requirement already satisfied: rich in /home/joonhai/.local/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (13.9.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/joonhai/.local/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/joonhai/.local/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/joonhai/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/joonhai/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (1.26.5)
# Requirement already satisfied: markdown>=2.6.8 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.7)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.1.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/joonhai/.local/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (0.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/joonhai/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.0.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/joonhai/.local/lib/python3.10/site-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/joonhai/.local/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/joonhai/.local/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/joonhai/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.1.2)

# %%
from langchain.docstore.document import Document
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# PDF 로드
pdf_path = "/home/joonhai/DSDC/한화 개인용 자동차보험.pdf"
loader = PyPDFLoader(pdf_path)
documents = loader.load()

# 텍스트 청크 생성
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=30)
chunks = text_splitter.split_documents(documents)
chunks = chunks[11:]  # 첫 11개 청크 제외 (필요 시 수정)

# 줄바꿈 제거 및 ID 부여
chunks = [
    Document(
        page_content=chunk.page_content.replace('\n', ' ').strip(),
        metadata=chunk.metadata
    ) for chunk in chunks
]
for i, chunk in enumerate(chunks):
    chunk.metadata['doc_id'] = i

print(f"생성된 텍스트 청크 수: {len(chunks)}")
# Out:
# 생성된 청크 수: 702

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
import faiss

# 임베딩 생성
embedding = HuggingFaceEmbeddings(model_name="BAAI/bge-m3")

# FAISS GPU 설정
res = faiss.StandardGpuResources()
cpu_index = FAISS.from_documents(documents=chunks, embedding=embedding).index
gpu_index = faiss.index_cpu_to_gpu(res, 0, cpu_index)

# GPU 기반 벡터 스토어 생성
vectorstore = FAISS(gpu_index, embedding)

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

# Ollama LLM 설정
llm = ChatOllama(model="llama3.1", temperature=0.8, num_predict=500)

# RAG 체인 구성
retrieval_prompt = ChatPromptTemplate.from_template("""
다음 컨텍스트를 바탕으로 질문에 답변해주세요. 관련 정보가 없으면 "답변할 수 없습니다."라고 답변해주세요.
컨텍스트: {context}
질문: {input}
답변:
""")
combine_docs_chain = create_stuff_documents_chain(llm, retrieval_prompt)
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 3})
rag_chain = create_retrieval_chain(retriever, combine_docs_chain)

# %%
import pandas as pd
import chardet
from sentence_transformers import CrossEncoder

# CSV 데이터 로드
qa_csv_path = "/home/joonhai/DSDC/자동차보험_qa_dataset.csv"

# 인코딩 감지 및 데이터 로드
with open(qa_csv_path, 'rb') as file:
    result = chardet.detect(file.read())
print(f"감지된 인코딩: {result['encoding']}")

df_qa_test = pd.read_csv(qa_csv_path, encoding=result['encoding'])
df_filtered_qa = df_qa_test[df_qa_test['doc_id'].between(1, 100)]

print(f"필터링된 데이터셋 크기: {len(df_filtered_qa)}")

# 유사도 계산 함수 정의
def calculate_cross_encoder_similarity(query: str, prediction: str, model_name="BAAI/bge-reranker-v2-m3") -> float:
    cross_encoder_model = CrossEncoder(model_name, device="cuda")  # GPU 사용
    sentence_pairs = [[query, prediction]]
    similarity_scores = cross_encoder_model.predict(sentence_pairs)
    return similarity_scores[0]

# %%
from multiprocessing import Pool, cpu_count

# RAG 체인을 통한 문서 검색 및 답변 생성
def evaluate_doc_ids(df_qa_subset):
    results = []
    for _, row in df_qa_subset.iterrows():
        question = row['question']
        ground_truth = row['answer']
        response = rag_chain.invoke({"input": question})
        prediction = response['answer']
        similarity = calculate_cross_encoder_similarity(ground_truth, prediction)
        results.append({
            "doc_id": row['doc_id'],
            "question": question,
            "ground_truth": ground_truth,
            "prediction": prediction,
            "similarity": similarity
        })
    return pd.DataFrame(results)

# 병렬 처리
def process_batch(batch):
    return evaluate_doc_ids(batch)

batch_size = 10
batches = [df_filtered_qa.iloc[i:i + batch_size] for i in range(0, len(df_filtered_qa), batch_size)]

if __name__ == "__main__":
    print("병렬 처리를 시작합니다...")
    with Pool(cpu_count()) as pool:
        parallel_results = pool.map(process_batch, batches)

    # 결과 병합 및 저장
    df_parallel_results = pd.concat(parallel_results, ignore_index=True)
    output_path = "/home/joonhai/DSDC/parallel_results.csv"
    df_parallel_results.to_csv(output_path, index=False, encoding='utf-8-sig')
    print(f"병렬 처리 완료: 결과 저장 경로 - {output_path}")
